# %%
pip install python-bcb
# Out:
# Collecting python-bcb
#   Downloading python_bcb-0.3.3-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: httpx>=0.24.0 in c:\users\edu_b\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from python-bcb) (0.28.1)
# Collecting lxml>=4.9.2 (from python-bcb)
#   Downloading lxml-6.0.2-cp314-cp314-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: pandas>=2.0.0 in c:\users\edu_b\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from python-bcb) (2.3.3)
# Requirement already satisfied: requests>=2.31.0 in c:\users\edu_b\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from python-bcb) (2.32.5)
# Requirement already satisfied: anyio in c:\users\edu_b\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from httpx>=0.24.0->python-bcb) (4.12.0)
# Requirement already satisfied: certifi in c:\users\edu_b\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from httpx>=0.24.0->python-bcb) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\edu_b\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from httpx>=0.24.0->python-bcb) (1.0.9)
# Requirement already satisfied: idna in c:\users\edu_b\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from httpx>=0.24.0->python-bcb) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\edu_b\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from httpcore==1.*->httpx>=0.24.0->python-bcb) (0.16.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\edu_b\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas>=2.0.0->python-bcb) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\edu_b\appdata\roaming\python\python314\site-packages (from pandas>=2.0.0->python-bcb) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\edu_b\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas>=2.0.0->python-bcb) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\edu_b\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from pandas>=2.0.0->python-bcb) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\edu_b\appdata\roaming\python\python314\site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->python-bcb) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\edu_b\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests>=2.31.0->python-bcb) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\edu_b\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from requests>=2.31.0->python-bcb) (2.6.2)
# Downloading python_bcb-0.3.3-py3-none-any.whl (19 kB)
# Downloading lxml-6.0.2-cp314-cp314-win_amd64.whl (4.1 MB)
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    -------------------------------------- - 3.9/4.1 MB 36.6 MB/s eta 0:00:01
#    ---------------------------------------- 4.1/4.1 MB 28.4 MB/s  0:00:00
# Installing collected packages: lxml, python-bcb
#
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 0/2 [lxml]
#    ---------------------------------------- 2/2 [python-bcb]
#
# Successfully installed lxml-6.0.2 python-bcb-0.3.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from bcb import sgs
import pandas as pd

# %%
df_bcb = sgs.get({'selic': 432, 'ipca': 433}, start='2016-01-01', end='2018-12-31')

# %%
print(df_bcb.head())
# Out:
#             selic  ipca
# Date
# 2016-01-01  14.25  1.27
# 2016-01-02  14.25   NaN
# 2016-01-03  14.25   NaN
# 2016-01-04  14.25   NaN
# 2016-01-05  14.25   NaN

# %%
df_bcb.info(), df_bcb.index
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1096 entries, 2016-01-01 to 2018-12-31
# Freq: D
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   selic   1096 non-null   float64
#  1   ipca    36 non-null     float64
# dtypes: float64(2)
# memory usage: 25.7 KB
# (None,
#  DatetimeIndex(['2016-01-01', '2016-01-02', '2016-01-03', '2016-01-04',
#                 '2016-01-05', '2016-01-06', '2016-01-07', '2016-01-08',
#                 '2016-01-09', '2016-01-10',
#                 ...
#                 '2018-12-22', '2018-12-23', '2018-12-24', '2018-12-25',
#                 '2018-12-26', '2018-12-27', '2018-12-28', '2018-12-29',
#                 '2018-12-30', '2018-12-31'],
#                dtype='datetime64[ns]', name='Date', length=1096, freq='D'))

# %%
df_bcb['ipca'].isnull().any()
# Out:
# np.True_

# %%
df_bcb.index = pd.to_datetime(df_bcb.index) # garantir que Index seja um datetime
df_bcb.index.name = 'Date'

# %%
df_bcb_mensal = df_bcb.resample('ME').agg({'selic': 'mean', 'ipca': 'last'})

# %%
df_bcb_mensal['selic_mensal'] = ((1 + (df_bcb_mensal['selic'] / 100))**(1/12) - 1) * 100
df_bcb_mensal['selic_mensal'] = df_bcb_mensal['selic_mensal'].round(4)
print(df_bcb_mensal.head(), df_bcb_mensal.tail())
# Out:
#             selic  ipca  selic_mensal
# Date
# 2016-01-31  14.25  1.27        1.1163
# 2016-02-29  14.25  0.90        1.1163
# 2016-03-31  14.25  0.43        1.1163
# 2016-04-30  14.25  0.61        1.1163
# 2016-05-31  14.25  0.78        1.1163             selic  ipca  selic_mensal
# Date
# 2018-08-31    6.5 -0.09        0.5262
# 2018-09-30    6.5  0.48        0.5262
# 2018-10-31    6.5  0.45        0.5262
# 2018-11-30    6.5 -0.21        0.5262
# 2018-12-31    6.5  0.15        0.5262

# %%
df_bcb_mensal = df_bcb_mensal.rename(columns={'ipca': 'ipca_mensal'})
print(df_bcb_mensal.columns)
# Out:
# Index(['selic', 'ipca_mensal', 'selic_mensal'], dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
PALETA_OLIST = ["#0047bb", "#94a3b8", "#1e293b", "#3b82f6", "#e2e8f0"]
sns.set_theme(style="whitegrid")
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=PALETA_OLIST)
plt.rcParams['figure.figsize'] = (10, 6)
plt.rcParams['axes.titlesize'] = 16
plt.rcParams['axes.titleweight'] = 'bold'

# %%
plt.plot(df_bcb_mensal.index, df_bcb_mensal['selic_mensal'], label='Selic média no mês (% a.m.)', linewidth=2)
plt.plot(df_bcb_mensal.index, df_bcb_mensal['ipca_mensal'],  label='IPCA mensal (% a.m)', linewidth=2)

plt.title('Selic x IPCA - Brasil (2016–2018)')
plt.xlabel('Data')
plt.ylabel('Taxa (%)')
plt.legend()
plt.tight_layout()
plt.show()

# %%
lags = [0, 3, 6, 12, 18, 24]

correlacoes = {}
for lag in lags:
    # Selic(t) vs IPCA(t + lag)
    corr = df_bcb_mensal['selic_mensal'].corr(df_bcb_mensal['ipca_mensal'].shift(-lag))
    correlacoes[lag] = corr

corr_series = pd.Series(correlacoes)

# %%
plt.bar(
    x=range(len(corr_series)),
    height=corr_series.values,
)

plt.plot(
    range(len(lags)),
    corr_series.values,
    color='darkred',
    marker='o',
    linewidth=2,
    label='Tendência'
)
plt.xticks(
    ticks=range(len(corr_series)),
    labels=[f'{lag}m à frente' for lag in corr_series.index]
)

plt.title('Correlação: Selic atual x IPCA em diferentes horizontes')
plt.xlabel('Defasagem (IPCA à frente)')
plt.ylabel('Correlação')
plt.tight_layout()
plt.show()
