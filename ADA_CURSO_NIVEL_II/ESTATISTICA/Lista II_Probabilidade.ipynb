# %% [markdown]
# # 📘 Lista de Exercícios: Probabilidade
#
# Esta lista contém **10 exercícios** sobre conceitos fundamentais de probabilidade.

# %% [markdown]
# ### Exercício 1
# Defina os seguintes termos:
# - Espaço amostral
# - Evento
# - Probabilidade clássica

# %% [markdown]
# ### Exercício 2
# Um dado honesto de 6 faces é lançado. Qual a probabilidade de sair um número maior que 4?
#
# Mostre os cálculos.

# %% [markdown]
# ### Exercício 3
# Um baralho tem 52 cartas. Qual a probabilidade de retirar:
# - a) Um Ás
# - b) Uma carta de Copas
# - c) Um Rei de Copas

# %% [markdown]
# ### Exercício 4
# Explique a diferença entre **evento simples**, **evento composto**, **eventos independentes** e **eventos mutuamente exclusivos**. Dê exemplos.

# %% [markdown]
# ### Exercício 5
# Simule, com Python, o lançamento de uma moeda 100 vezes. Calcule a frequência relativa de caras e coroas e compare com a probabilidade teórica (0.5).

# %% [markdown]
# ### Exercício 6
# Um dado é lançado duas vezes. Qual a probabilidade de:
# - a) A soma ser igual a 7
# - b) A soma ser maior que 9
# - c) Ambos os lançamentos serem pares

# %% [markdown]
# ### Exercício 7
# Suponha que a probabilidade de chover amanhã seja 0,3. Qual a probabilidade de **não chover**? Explique seu raciocínio.

# %% [markdown]
# ### Exercício 8
# Simule, com Python, o lançamento de um dado 10.000 vezes e faça um gráfico de barras com as frequências relativas de cada face.

# %% [markdown]
# ### Exercício 9
# Uma urna contém 3 bolas vermelhas, 2 azuis e 5 verdes. Uma bola é retirada ao acaso. Qual a probabilidade de sair:
# - a) Uma bola vermelha
# - b) Uma bola azul ou verde

# %% [markdown]
# ### Exercício 10
# Explique o conceito de **frequência relativa** e como ela se aproxima da probabilidade teórica com o aumento do número de experimentos. Ilustre com um exemplo prático.
