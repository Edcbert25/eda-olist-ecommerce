# %%
# VETORES da BASE CANONICA como vetores linha (listas)

e1 = [1, 0]
e2 = [0,1]

print(e1)
print()
print(e2)
# Out:
# [1, 0]
#
# [0, 1]

# %%
# Um vetor que não pode ser representado através de outro são considerados linermente independentes
