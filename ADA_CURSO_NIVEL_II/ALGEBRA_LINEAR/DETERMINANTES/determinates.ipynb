# %%
### DETERMINANTES

import numpy as np

matriz = np.array([[1, 2, -3], [2, 1, 3], [2, 0, -1]])

# %%
matriz
# Out:
# array([[ 1,  2, -3],
#        [ 2,  1,  3],
#        [ 2,  0, -1]])

# %%
det = np.linalg.det(matriz)

# %%
det
# Out:
# np.float64(20.99999999999999)

# %%
matriz_a = np.random.randint(0, 10, size=(4, 4))

# %%
matriz_a
# Out:
# array([[1, 5, 6, 8],
#        [3, 8, 9, 3],
#        [9, 0, 4, 3],
#        [9, 7, 4, 6]], dtype=int32)

# %%
det_a = np.linalg.det(matriz_a)

# %%
det_a
# Out:
# np.float64(-3167.999999999998)

# %%
matriz_b = np.random.randint(0, 10, size=(3, 4)) # MATRIZ 3 X 4 - NÃO É MATRIZ QUADRADA.

# %%
# NÃO SE CALCULA O DETERMINANTE DE UMA MATRIZ QUE NÃO É QUADRADA
# (OU SEJA, TENHA O NÚMERO DE LINHAS DIFERENTE DE COLUNAS)

matriz_b = np.linalg.det(matriz_b)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[20], line 4
#       1 # NÃO SE CALCULA O DETERMINANTE DE UMA MATRIZ QUE NÃO É QUADRADA
#       2 # (OU SEJA, TENHA O NÚMERO DE LINHAS DIFERENTE DE COLUNAS)
# ----> 4 matriz_b = np.linalg.det(matriz_b)
#
# File c:\Users\edu_b\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\numpy\linalg\_linalg.py:2428, in det(a)
#    2382 """
#    2383 Compute the determinant of an array.
#    2384
#    (...)   2425
#    2426 """
#    2427 a = asarray(a)
# -> 2428 _assert_stacked_square(a)
#    2429 t, result_t = _commonType(a)
#    2430 signature = 'D->D' if isComplexType(t) else 'd->d'
#
# File c:\Users\edu_b\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\numpy\linalg\_linalg.py:264, in _assert_stacked_square(*arrays)
#     261     raise LinAlgError('%d-dimensional array given. Array must be '
# ...

# %%
### RESOLVENDO EQUAÇÕES LINEARES NA FORMA MATRICIAL
# Definimos a matriz A e o vetor B
A = np.array([[1, 2, 3], [2, 3, 3], [1, 2, 0]])
B = np.array([1, -3, 6])

# %%
A
# Out:
# array([[1, 2, 3],
#        [2, 3, 3],
#        [1, 2, 0]])

# %%
B
# Out:
# array([ 1, -3,  6])

# %% [markdown]
# A x = B
#
# x = A_inv * B

# %%
A_inv = np.linalg.inv(A)
A_inv

# %% [markdown]
# X = np.linalg.solve(A, B)
#
# ###  OU
#
# X = np.dot(A_inv, B)

# %%
X = np.dot(A_inv, B)
X

# %%
X_solve = np.linalg.solve(A, B) # Solução usando linalg.solve
X_solve
