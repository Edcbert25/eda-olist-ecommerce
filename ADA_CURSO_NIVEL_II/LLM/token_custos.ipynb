# %%
pip install openai

# %%
from openai import OpenAI

client = OpenAI(
  api_key="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"
)

response = client.responses.create(
  model="gpt-5-nano",
  input="write a haiku about ai",
  store=True,
)

print(response.output_text);

# %%
### chamando a fç ChatCompletion.create da biblioteca OpenAI para iniciar uma interação com o modelo GPT - 3.5-turbo.

review = "O novo smartphone da marca X é incrível, com a bateria de longa duração e uma câmera de alta qualidade."

response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        
        {"role": "user", "content": f"Quais são os principais pontos positivos elencados pelo cliente na seguinte review de um produto: {review}"}
        
    ]
)

# %%
print(response.choices[0].message.content)

# %%
### função ChatCompletion.create para perguntar sobre LLMs

response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        
        {"role":"user", "content":"No contexto dos modelos de linguagem, explique a diferença entre LLMs open-source e closed-source."}
    ]
)

# %%
print(response.choices[0].message.content)

# %%
### custos utilização API
## regra de bolso (Estimativa)

frase = "Isso é uma frase"
n_palavras = len(frase.split())
print(f"Número de palavras: {n_palavras}")

n_tokens = int(n_palavras/0.75)
print(f"Número de tokens: {n_tokens}")

# %%
### OpenAI Platform

# platform.openai.com/tokenizer

# %%
# !python - m pip install tiktoken

# %%
import tiktoken

enc = tiktoken.encoding_for_model("gpt-3.5-turbo")

n_tokens_tiktoken = len(enc.encode(frase))

# %%
print(f"Número de tokewns: {n_tokens_tiktoken}")

# %%
custo_por_token = {
    "gpt-4-turbo": {
        "input": 0.1,
        "output": 0.3
    },
    "gpt-3.5-turbo": {
        "input": 0.001,
        "output": 0.002
    }
}

# %%
### openai.com/pricing

# %%
n_tokens_tiktoken = len(enc.encode(review))

# %%
modelo = "gpt-3.5-turbo"

custo_input_tokens = (custo_por_token.get(modelo).get('input')*n_tokens_tiktoken)/1000

# %%
print(f"$ {custo_input_tokens:.5f}")

# %%
# custo de output tokens

review = "O novo smartphne da marca X é incrível, com uma bateria de lonfa duração e uma camera de alta qualidade."

response = client.chat.completions.create(
    model="gpt-3.5-turbo",
    messages=[
        
        {"role":"user", "content": f"Quais são os principais pontos positivos elencados pelo cliente na seguinte review do produto: {review}"}
    ],
    max_tokens = 300 # travando o tamanho máximo das respostas
)

response_text = response.choices[0].message.content

# %%
print(response_text)

# %%
custo_output_tokens = (custo_por_token.get(modelo).get('output')*300)/1000

# %%
print(f"$ {cust_output_tokens:.5f}")

# %%
custo_total = custo_output_tokens + custo_input_tokens

# %%
print(f"custo total da requisição (GPT 3.5 Turbo): $ {custo_total:.5f} ou {custo_total*5:.5f}")
