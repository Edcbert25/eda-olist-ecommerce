# %% [markdown]
# ## Funções

# %% [markdown]
# Funções são uma espécie de "subprograma"
#
# Elas são como pequenos pedaços de programa que podemos usar para resolver problemas específicos
#
# São um comando de bloco e, assim como `if`, `else`, `while`, elas pedem `:` e tab na linha abaixo para caracterizar o código que está dentro e fora do bloco.
#
# Para criar funções a gente usa o comando `def` seguido do nome da função:

# %% [markdown]
# A estrutura de **definição de uma função** é dada por:
# <br><br>
# <br>
# ```python
# def nomeDaFuncao(param1, param2, ...):
#     """Docstring: escrever como funciona a tua função"""
#
#     processamento ou instrucoes
#
#     return saida
# ```
# <br>
#
# ou seja:
# * inicia por `def`,
# * depois o nome da função
# * depois os parâmetros em parênteses.
# * em seguida podemos descrever a função no """ """ e, por fim
# * escrever a sequência de intruções da função **respeitando a identação**, podendo retornar algum objeto.
#
# > Assim como no `for`, `if` e `while` a identação do código é fundamental para definir o que está contido dentro da função.

# %% [markdown]
# Quando uma função é chamada pelo nome, o fluxo do programa principal é pausado.
#
# Em seguida a função inteira é executada, e, ao final, ela volta ao programa principal.

# %%
print("Antes de chamar a função")
printar()
print("Depois de chamar minha função")

# %% [markdown]
# Nomes de funções devem começar por strings ou "_" e deve-se respeitar as letras maiúsculas e minúsculas:

# %%
def 1():
    print("oi")

# %% [markdown]
# ## Por que funções são importantes em um código?
#
# - Reuso de código: Você escreve uma vez e usa em vários lugares, sem precisar copiar e colar.
#
# - Organização e clareza: Deixa o código mais legível, separado em blocos com nomes que descrevem o que fazem.
#
# - Facilidade de manutenção: Se precisar mudar a lógica, altera em um único lugar.
#
# - Testabilidade: Fica mais fácil criar testes unitários para partes específicas do código.
#
# - Colaboração em equipe: Cada pessoa pode trabalhar em funções diferentes, sem atrapalhar o restante.

# %%
# função que calcula o tamnho de um objeto iterável igual a len()
objeto =  [2, 3, 4, 5, 6]
def calcula_tamanho(objeto):
    tamanho = 0
    for item in objeto:
        tamanho+= 1
    print(tamanho)
    
calcula_tamanho(objeto)

# %%
calcula_tamanho("caixaverso") # FAZ A MESMA COM COISA QUE LEN () DO PYTHON

# %%
calcula_tamanho({"ola", "pessoas", "do", "caixaverso"})

# %% [markdown]
# > Exemplo de como o código da prefeitura está organizado para tornar o arquivo principal chamado `flows.py` em um código fácil de ser entendido.

# %% [markdown]
# ## Exemplo:
# Suponha que em todo novo cadastro de usuário você precise validar se o CPF é numérico.
#
# Em vez repetir sempre o mesmo código:

# %%
cpf_1 = "12345678901"
print(len(cpf_1) == 11 and cpf_1.isdigit())

cpf_2 = "1234abc"
print(len(cpf_2) == 11 and cpf_2.isdigit())

# %% [markdown]
# Podemos criar uma função e chamá-la toda vez que precisamos validar

# %%
def validar_cpf(cpf):
    print(len(cpf) == 11 and cpf.isdigit())
    
validar_cpf(cpf_1)

# %% [markdown]
# ### Hands on
# Continuando o exemplo da aula passada, crie uma função que valide se a string é um email válido.
# Depois de usar a função em uma string, crie loop for / list comprehension para retornar `True` para e-mails válidos e `False` caso contrário usando a função.

# %%
lista_emails= [
    "joao@gmail.com",
    "123456",
    "exemplo.com",
    "fulano@yahoo.com",
    "beltrano",
    "ciclano@gmail.com",
    "teste",
    "outroexemplo.com",
    "enivaldo@gmail.com"
]

def validar_email(email: list) -> list:
    lista_emails_validos = [
        True if "@" in item and ".com" in item else False
        for item in email
    ]
    return lista_emails_validos

validar_email(lista_emails)

# %% [markdown]
# ## Parâmetros vs argumentos

# %% [markdown]
# Quando definimos a função as variáveis que estão dentro do parênteses, como inputs, são o que chamamos de `parâmetros`.
#
# ```python
# def nomeDaFuncao(param1, param2, ...):
#     ...
#     return
# ```

# %% [markdown]
# Já quando chamamos a função, passamos `argumentos` como valores de input da função:
#
# ```python
# nomeDaFuncao(arg1, arg2)
# ```
# <br>

# %% [markdown]
# A ideia de escrever funções é que muitas vezes tem algo que eu faço com frequência na lógica do meu negócio.
#
# Toda vez que eu rodo a função, preciso ter como mudar os valores que ela vai usar nos cálculos ou transformações.
#
# Por conta disso, quando a gente define uma função é possível passarmos informações adicionais para ela. Chamamos essas informações de "parâmetros".
#
# Ao definir a função, damos nomes para cada um desses parâmetros que serão utilizados com esse mesmo nome dentro da função.
#
# > “O parâmetro é o rótulo; o argumento é o conteúdo que você coloca nele.”

# %% [markdown]
# Quando a gente passa o valor dos parâmetros eles não necessariamente precisam ser fixos, pode ser uma variável, por exemplo

# %% [markdown]
# Uma função pode receber vários parâmetros, basta separar com vírgula:

# %% [markdown]
# Se passarmos os argumentos fora de ordem esperada dos parâmetros na hora de chamar a função o código pode ficar errado

# %% [markdown]
# Ele sempre vai entender os argumentos como se estivessem sendo enviados na mesma ordem dos parâmetros.

# %% [markdown]
# Mas podemos passar fora de ordem. Para isso precisamos explicitar qual parâmetro é qual

# %% [markdown]
# ### Variáveis globais x locais
#
# Em Python, as variáveis criadas dentro de uma função **só existem dentro dela** — esse espaço é chamado de escopo local.
# Já as variáveis criadas fora da função pertencem ao escopo global, e o Python trata essas duas como coisas diferentes, mesmo que tenham o mesmo nome.

# %%
# tentando acessar variável interna da função fora dela dá erro
def ola(nome1):
    print('Olá, eu sou', nome1)
ola('Priscila')
nome1

# %%
# utilizar variável externa dentro da função dá certo, mas não é recomendado
def ola(nome):
    print('Olá, eu sou', nome1)
    
nome1 = "Aqui é um nome fora da função"
ola('Priscila')

# %% [markdown]
# Suponha que temos a função `adiciona_ddi_telefone` que recebe "telefone" como parâmetro e acrescenta "+55" e que também temps uma variável `telefone` no código:

# %%
def adiciona_ddi_telefone(telefone):
    telefone = '+55'+telefone
    print(f"Telefone dentro da função {telefone}\n")

telefone = "16982567787"
print(f"Meu telefone antes da função é {telefone}\n")
adiciona_ddi_telefone(telefone)
print(f"Meu telefone depois da função é {telefone}\n")

# %% [markdown]
# O telefone dentro da função existe só enquanto a função roda.
# Ele não muda o valor do telefone de fora, porque está em outro “ambiente” de memória.
# Isso evita confusão e permite que cada função tenha suas próprias variáveis sem afetar o restante do programa.

# %% [markdown]
# ## `return`
#
# Uma função pode ter uma "resposta".
#
# Por exemplo, nossa função pode ser um cálculo e o resultado desse cálculo pode ser útil em nosso programa.
#
# Dizemos que essas funções "retornam" um valor.
#
# Utilizamos a palavra "return" para fazer uma função retornar sua resposta.
#
# Quando uma função retorna um valor, ela pode ser usada em expressões
# matemáticas e lógicas, ter seu valor atribuido a uma variável etc.

# %%
# com nossa função anterior
def adiciona_ddi_telefone(telefone):
    return '+55'+ telefone

adiciona_ddi_telefone("996225854")

# %%
# com nossa função anterior
def validar_cpf(cpf):
    return len(cpf) == 11 and cpf.isdigit()

cpf_valido = validar_cpf("12345678911")
cpf_valido

# %% [markdown]
# ## Hands on
# crie a função `celsius_para_fahrenheit` que vai receber um valor numérico em celsius e converter para fahrenheit utilizando a expressão `(celsius * 9/5) + 32` e com a saída dela print "Amanhã dá praia" se a temperatura em fahrenheit for maior ou igual a 80 e "Amanhã não dá praia" caso contrário.

# %%
def celsius_para_fahrenheit(celsius: float) -> str:
    return "vai dar praia" if (celsius * 9/5 + 32) >= 90 else "Amanhã não dá praia"

celsius_para_fahrenheit()

# %% [markdown]
# ### Mais de um valor no return
#
# Eu consigo ter mais de um retorno da minha função? Suponha a função `desmembrar_telefone` que retorna o número do ddd separado do resto do telefone:

# %%
def desmembrar_telefone(numero: str) -> tuple[int, list[str]]:
    ddd = numero[:2]
    digitos = numero[2:]
    return int(ddd), digitos

ddd, digitos = desmembrar_telefone("23996554578")
print(ddd)
print(digitos)

# %% [markdown]
# Olha a tupla!

# %% [markdown]
# Vamos fazer alguns testes com o `return`:

# %%
def teste():
    print('A')
    return 'B' ## Quando a função acha um return ela para imediatamente
    print('C')
teste()

# %% [markdown]
# Toda vez que chegamos em um `return` saímos de dentro da função. É como se fosse um ponto de parada indicando seu fim.

# %% [markdown]
# Mas também podemos fazer o uso antecipado do return para evitar passar por partes desnecessárias do código.

# %%
def verificar_login(usuario, senha):
    # Caso o usuário ou senha estejam vazios, sai logo
    if not usuario or not senha:
        return "Usuário ou senha não informados."

    # Verifica se as credenciais estão corretas
    if usuario == "admin" and senha == "1234":
        return "Login bem-sucedido!"

    # Se chegou até aqui, é porque as credenciais estão erradas
    return "Usuário ou senha incorretos."

print(verificar_login("", "1234"))       # Sai logo com return antecipado
print(verificar_login("admin", "1234"))  # Login bem-sucedido
print(verificar_login("user", "9999"))   # Usuário incorreto

# %% [markdown]
# é o mesmo que fazer:

# %%
def verificar_login(usuario, senha):
    # Caso o usuário ou senha estejam vazios, sai logo
    if not usuario or not senha:
        return "Usuário ou senha não informados."

    # Verifica se as credenciais estão corretas
    if usuario == "admin" and senha == "1234":
        return "Login bem-sucedido!"
    else:
        return "Usuário ou senha incorretos."

print(verificar_login("", "1234"))       # Sai logo com return antecipado
print(verificar_login("admin", "1234"))  # Login bem-sucedido
print(verificar_login("user", "9999"))   # Usuário incorreto

# %%
def verificar_login(usuario, senha):
    # Caso o usuário ou senha estejam vazios, sai logo
    if not usuario or not senha:
        saida = "Usuário ou senha não informados."

    # Verifica se as credenciais estão corretas
    if usuario == "admin" and senha == "1234":
        saida = "Login bem-sucedido!"

    # Se chegou até aqui, é porque as credenciais estão erradas
    saida = "Usuário ou senha incorretos."
    return saida

print(verificar_login("", "1234"))       # Sai logo com return antecipado
print(verificar_login("admin", "1234"))  # Login bem-sucedido
print(verificar_login("user", "9999"))   # Usuário incorreto

# %% [markdown]
# Por que usar o return antecipado aqui?
# Porque não faz sentido continuar processando o código se o usuário ou a senha estão vazios. Isso economiza tempo e torna o fluxo mais limpo.

# %% [markdown]
# ## Algumas curiosidades:
#
# ### Podemos ter funções dentro de listas e dicionários

# %%
def func():
    print("Você chamou a função func()!")

print(("cat", func, 42))

# %%
objects = ["cat", func, 42]
objects

# %%
objects[1]()

# %%
d = {"cat": 1, "key_func": func, 42: 3}

# %%
d["key_func"]()

# %% [markdown]
# ### Podemos atribuir função a uma variável
# Ou seja, fazer com que uma variável nossa seja uma função ao invés de ser uma string, lista, dicionário...

# %%
def quadrado(x):
    return x ** 2

operacao = quadrado
operacao

# %%
print(quadrado(2))
print(operacao(2))

# %%
type(operacao)

# %%
operacao=quadrado

# é o mesmo que fazer

def quadrado(x):
    return x ** 2

def operacao(x):
    return x ** 2

# %% [markdown]
# ### Podemos criar funções dentro de funções

# %%
def calcular_operacao(numero):
    def dobro(x):
        return x * 2

    def metade(x):
        return x / 2

    return dobro(numero), metade(numero)

resultado = calcular_operacao(5)
print(resultado)

# %% [markdown]
# ### E, por fim, podemos passar a função como argumento de outra função

# %% [markdown]
# Suponha que tenho as funções:

# %%
def dobro(x):
    return x * 2

def metade(x):
    return x / 2

def quadrado(x):
    return x ** 2

# %%
listas_funcoes = [dobro, metade, quadrado]
listas_funcoes

# %%
[fun(10) for func in listas_funcoes]

# %% [markdown]
# E quero criar uma nova função que vai ser responsável por selecionar qual das duas operações será aplicada no meu valor `x`

# %%
def calcular_operacao(numero, operacao):
    return operacao(numero)

resultado = calcular_operacao(5, operacao=dobro)
print(resultado)

# %%
resultado = calcular_operacao(5, operacao=metade)
resultado

# %%
resultado = calcular_operacao(5, operacao=quadrado)
resultado

# %% [markdown]
# Nesse exemplo, a função `calcular_operacao` recebe duas argumentos: numero e funcao. <br>
# Ela chama a função `operacao` como argumento e aplica a operação que foi determinada para o `numero`.
#
# No exemplo, passamos a função `dobro` como argumento e obtemos o resultado da aplicação dessa função ao número 5.

# %% [markdown]
# ## 🎯 Exercícios 🎯 <a class="anchor" id="quatro"></a>

# %% [markdown]
# **1)** Faça uma função que recebe o valor do raio de um círculo e retorna o valor do comprimento de sua circunferência: C = 2 * pi * r.

# %%
python -m pip install numpy
import numpy as np
def calcula_circunferencia(raio):
    return 2*np.pi*raio

raio = 10 
calcula_circunferencia(raio)
# Out:
#   Cell In[48], line 1
#     python -m pip install numpy
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# **2)** Faça uma função que recebe um nome e um horário (em 24h) e imprime “Bom dia, [nome]”, caso seja antes de 12h, “Boa Tarde, [nome]”, caso seja entre 12h e 18h e “Boa noite, [nome]” se for após às 18h.

# %%
def saudacao(nome, horario):
    if horario < 12:
        return f"Bom dia, {nome}"
    elif 12 <= horario < 18:
        return f"Boa Tarde, {nome}"
    else:  # horário >= 18
        return f"Boa noite, {nome}"
    
saudacao("Yasmim", 15)
# Out:
# 'Boa Tarde, Yasmim'

# %% [markdown]
# **3)** Faça uma função que recebe um número e retorne True se ele é par ou False, se não.

# %%
def verifica_par(numero):
    return True if numero % 2 == 0 else False

num = 21
verifica_par(num)
# Out:
# False

# %% [markdown]
# **4)** Uma empresa de logística precisa calcular o custo total de envio de uma mercadoria para diferentes clientes.
#
# O custo é composto por:
#
# - peso do produto (em kg) multiplicado pelo valor do frete por kg,
#
# - uma taxa fixa de manuseio (igual para todos os envios).
#
# Escreva uma função que receba o peso do produto, o valor do frete por kg e a taxa fixa, e calcule o custo final do envio.

# %%
def calcula_custo_final(peso_produto, taxa_fixa):

# %% [markdown]
# **5)** Crie uma função que compare o valor final de um investimento em cdi + uma taxa com o de ipca + uma taxa
#
# Cálculo de valor final ao ser acrescido uma taxa anual
#
# $valor_{final} = valor_{inicial} * ((1 + taxa_{efetiva})^{anos})$

# %% [markdown]
# ____
# ____

# %% [markdown]
# # Funções geradoras e a palavra reservada yield
#
# Mas o que fazer quando os dados são imensos (ou talvez infinitos) e não seja possível realizar uma simples transformação ou filtragem?
#
# Então é necessário criar uma expressão geradoras mais sofisticada, as **funções geradoras**.
#
# Mas, para criarmos um função geradora, precisamos entender como utilizar a palavra **yield**, e pra entendermos, precisamos entender o que são **iteradores** vs iteraveis.

# %% [markdown]
# ## iteradores vs iteraveis

# %% [markdown]
# Todo objeto que contém dados e conseguimos percorrer pelo laço `for` é um **iterável**.<br>
# Por exemplo, uma lista, uma string. Os iteráveis possuem seus dados armazenados na memória e, por tanto, podemos acessar sempre que chamamos o objeto.
#
# Por outro lado, **iteradores** são objetos que geram os dados à medida que é pedido (soa familiar?).<br>
# Portanto, uma expressão geradora é um iterador.
#
# Podemos criar iteradores a partir de uma lista, utilizando `iter`:
#
# ```python
# lista = [0,10,11,9,4,3]
# iterador = iter(lista)
# ```

# %% [markdown]
# ## Yield

# %% [markdown]
# A palavra reservada **yield** (tradução: _produzir_) é usada em Python para criar uma **função geradora**. <br>
# Yield é muito semelhante a palavra _return_ nas funções que aprendemos:
#
# ao utilizar _yield_ em uma função geradora, a função **pausa** naquele ponto, retornando o valor pedido (até aí igual ao _return_).
# Porém, ao ser chamada novamente, a função continua de onde parou até um próximo yield. E assim por diante, até terminar a função.
#
# Aqui está um exemplo simples para ilustrar o uso da palavra yield em uma função geradora:

# %%
# gerador de numeros pares (indicar uma flag de inicio da funcao)
def numeros_pares():
    n = 0
    print('inicio da funcao')
    while True:
        yield n
        n += 2

gerador = numeros_pares()

# %% [markdown]
# Sempre que quisermos chamar os valores da função geradora, utilizamos a função `next`, que retorna o próximo valor a ser gerado pela função geradora.

# %%
print(next(gerador))  # Saída: 0
print(next(gerador))  # Saída: 2
print(next(gerador))  # Saída: 4

# %% [markdown]
# Repara que a flag de inicio da função foi printada apenas uma vez (sabe dizer o porquê?). Qual seria o resultado se fosse uma função?

# %% [markdown]
# # Funções geradoras e a palavra reservada yield
#
# Mas o que fazer quando os dados são imensos (ou talvez infinitos) e não seja possível realizar uma simples transformação ou filtragem?
#
# Então é necessário criar uma expressão geradoras mais sofisticada, as **funções geradoras**.
#
# Mas, para criarmos um função geradora, precisamos entender como utilizar a palavra **yield**, e pra entendermos, precisamos entender o que são **iteradores** vs iteraveis.

# %% [markdown]
# ## iteradores vs iteraveis

# %% [markdown]
# Todo objeto que contém dados e conseguimos percorrer pelo laço `for` é um **iterável**.<br>
# Por exemplo, uma lista, uma string. Os iteráveis possuem seus dados armazenados na memória e, por tanto, podemos acessar sempre que chamamos o objeto.
#
# Por outro lado, **iteradores** são objetos que geram os dados à medida que é pedido (soa familiar?).<br>
# Portanto, uma expressão geradora é um iterador.
#
# Podemos criar iteradores a partir de uma lista, utilizando `iter`:
#
# ```python
# lista = [0,10,11,9,4,3]
# iterador = iter(lista)
# ```

# %% [markdown]
# ## Yield

# %% [markdown]
# A palavra reservada **yield** (tradução: _produzir_) é usada em Python para criar uma **função geradora**. <br>
# Yield é muito semelhante a palavra _return_ nas funções que aprendemos:
#
# ao utilizar _yield_ em uma função geradora, a função **pausa** naquele ponto, retornando o valor pedido (até aí igual ao _return_).
# Porém, ao ser chamada novamente, a função continua de onde parou até um próximo yield. E assim por diante, até terminar a função.
#
# Aqui está um exemplo simples para ilustrar o uso da palavra yield em uma função geradora:

# %%
def numeros_pares():
    n = 0
    print('Inicio da funcao geradora')
    while True:
        yield n
        n += 2
        
gerador = numeros_pares()

# %% [markdown]
# Sempre que quisermos chamar os valores da função geradora, utilizamos a função `next`, que retorna o próximo valor a ser gerado pela função geradora.

# %%
print(next(gerador))
print(next(gerador))
print(next(gerador))

# %% [markdown]
# Repara que a flag de inicio da função foi printada apenas uma vez (sabe dizer o porquê?). Qual seria o resultado se fosse uma função?

# %% [markdown]
# # Dicas e Boas Práticas
#
# Deu pra perceber que agora as coisas ficaram um pouco mais sofisticadas, não é mesmo? Mas não adianta utilizar tudo o que aprendeu se não consegue passar clareza e interpretabilidade para as outras pessoas que vão reutilizar analisar ou revisar o teu código. Portanto, vão aqui algumas dicas:
#
# **Legibilidade do código:**
#
# Ao utilizar compreensão de listas e expressões geradoras, é importante manter o código legível e compreensível. Evite criar expressões muito complexas ou muito longas, pois isso pode dificultar a leitura e manutenção do código.
# Utilize nomes significativos para as variáveis dentro das expressões, de forma a tornar o propósito do código mais claro.
#
# **Utilize comentários:**
#
# Adicione comentários explicativos quando utilizar compreensão de listas e expressões geradoras complexas, especialmente se elas tiverem várias etapas ou condições.
# Comentários ajudam a documentar o código e torná-lo mais fácil de entender para você e outros desenvolvedores.
#
# **Considere o desempenho:**
#
# Embora as compreensões de listas e as expressões geradoras sejam ferramentas poderosas, é importante considerar o desempenho ao utilizá-las.
# Se estiver lidando com uma grande quantidade de dados, uma expressão geradora pode ser mais eficiente em termos de uso de memória e tempo de execução em comparação com a criação de uma lista completa.
# No entanto, é sempre recomendável fazer medições e testes para avaliar o desempenho real do seu código em cenários específicos.
#
# **Combine com outras funcionalidades:**
#
# As compreensões de listas e expressões geradoras podem ser combinadas com outras funcionalidades da linguagem Python, como funções embutidas (map, filter, etc.) e módulos especializados (como itertools) para realizar operações mais avançadas.
# Explore a documentação da linguagem Python para descobrir recursos e funcionalidades adicionais que possam aprimorar suas compreensões de listas e expressões geradoras.
# Lembre-se de encorajar seus alunos a praticar e experimentar por conta própria. Eles podem tentar resolver problemas utilizando compreensão de listas e expressões geradoras, para aprimorar sua familiaridade e habilidades com esses conceitos.

# %% [markdown]
# **12)** DESAFIO HEAVY METAL!! - Faça um jogo de BlackJack usando funções: o BlackJack, ou Vinte e Um, é um jogo em que os jogadores podem comprar cartas livremente, enquanto tiverem menos de 21 pontos. No nosso jogo, o Ás vale um ponto; as cartas de 2 a 10 valem o número de pontos que elas representam; e Valete, Dama e Rei valem 10 pontos cada. Ganha o jogador que tiver o maior número de pontos, desde que este seja menor ou igual a 21. Nosso jogo deve ter as seguintes
#
# #### Funções:
#
# a. Função principal: a função que vamos chamar para iniciar o jogo. Essa função não irá receber nem retornar nenhuma variável. Ela deve perguntar o número de jogadores participantes e o nome de cada um. Em seguida ela chama as outras funções do jogo.
#
# b. Função para criar o baralho: essa função deve criar um baralho (uma lista) com as cartas do baralho.
#
# c. Função para a jogada: essa função deve receber o nome do
# jogador que irá realizar a jogada e, caso ele ainda esteja ativo
# (tenha menos de 21 pontos e ainda não tenha desistido de
# comprar cartas) deve perguntar se ele quer comprar uma carta.
# Se ele responder que sim, a função deve chamar a próxima
# função para sortear uma carta e somar o valor retornado na
# pontuação do jogador; se ele responder que não, a função deve
# desativar o jogador para que ele não possa mais comprar cartas;
# Essa função só deve ser chamada enquanto houver jogadores
# ativos.
#
# d. Função para o sorteio: essa função retira uma carta aleatória do
# baralho e retorna o número de pontos que essa carta vale.
# e. Função verificação: verifica e indica qual/quais
# jogador/jogadores tem o maior número de pontos, que seja
# menor ou igual a 21.
